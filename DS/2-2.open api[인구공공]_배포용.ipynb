# %% [markdown]
# # 우리 동네 인구 구조 시각화 하기
# https://jumin.mois.go.kr/index.jsp#

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ## 데이터 기초 정보 파악

# %%
#라이브러리 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 데이터 로드
df = pd.read_csv('./data/population.csv')
df.head(10)
# Out:
#                           행정구역 2022년08월_남_총인구수 2022년08월_남_연령구간인구수  \
# 0          서울특별시  (1100000000)       4,601,295          4,601,295
# 1       서울특별시 종로구 (1111000000)          69,408             69,408
# 2  서울특별시 종로구 청운효자동(1111051500)           5,392              5,392
# 3    서울특별시 종로구 사직동(1111053000)           4,124              4,124
# 4    서울특별시 종로구 삼청동(1111054000)           1,130              1,130
# 5    서울특별시 종로구 부암동(1111055000)           4,476              4,476
# 6    서울특별시 종로구 평창동(1111056000)           8,345              8,345
# 7    서울특별시 종로구 무악동(1111057000)           3,757              3,757
# 8    서울특별시 종로구 교남동(1111058000)           4,579              4,579
# 9    서울특별시 종로구 가회동(1111060000)           1,830              1,830
#
#   2022년08월_남_0세 2022년08월_남_1세 2022년08월_남_2세 2022년08월_남_3세 2022년08월_남_4세  \
# 0        21,115        23,013        23,458        25,684        26,926
# 1           232           248           270           261           299
# 2            24            24            28            21            27
# 3            17            14            15            21            24
# 4             2             3             2             2             4
# 5            11            12            16            13            14
# 6            36            42            49            53            64
# 7            18            21            18            17            30
# 8            27            35            34            34            39
# 9             8            11             3            12             6
#
#   2022년08월_남_5세 2022년08월_남_6세  ... 2022년08월_여_91세 2022년08월_여_92세  \
# 0        29,115        33,125  ...          5,718          4,987
# 1           320           426  ...            126            104
# 2            44            47  ...             13              4
# 3            30            37  ...             13              8
# 4             4             6  ...              1              5
# 5            23            34  ...             15              8
# 6            50            72  ...             20             13
# 7            33            34  ...              3              3
# 8            30            51  ...              5              6
# 9            11            12  ...              4              5
#
#   2022년08월_여_93세 2022년08월_여_94세 2022년08월_여_95세 2022년08월_여_96세 2022년08월_여_97세  \
# 0          4,157          3,135          2,326          1,504          1,032
# 1             78             77             49             29             20
# 2              6              5              2              3              0
# 3              8              3              2              4              3
# 4              0              2              0              0              1
# 5             11              8              6              1              1
# 6             12             16             13              5              3
# 7              5              6              5              0              0
# 8              4              3              1              1              2
# 9              1              5              2              2              1
#
#   2022년08월_여_98세 2022년08월_여_99세 2022년08월_여_100세 이상
# 0            773            704              1,292
# 1             13             15                 28
# 2              2              1                  2
# 3              0              3                  0
# 4              0              0                  2
# 5              0              0                  5
# 6              3              2                  8
# 7              0              2                  4
# 8              0              0                  2
# 9              2              0                  0
#
# [10 rows x 207 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 
# Index(['행정구역', '남_총인구수', '남_연령구간인구수', '남_0세', '남_1세', '남_2세', '남_3세', '남_4세',
#        '남_5세', '남_6세',
#        ...
#        '여_91세', '여_92세', '여_93세', '여_94세', '여_95세', '여_96세', '여_97세', '여_98세',
#        '여_99세', '여_100세 이상'],
#       dtype='object', length=207)

# %%
df.head()
# Out:
#                           행정구역     남_총인구수  남_연령구간인구수    남_0세    남_1세    남_2세  \
# 0          서울특별시  (1100000000)  4,601,295  4,601,295  21,115  23,013  23,458
# 1       서울특별시 종로구 (1111000000)     69,408     69,408     232     248     270
# 2  서울특별시 종로구 청운효자동(1111051500)      5,392      5,392      24      24      28
# 3    서울특별시 종로구 사직동(1111053000)      4,124      4,124      17      14      15
# 4    서울특별시 종로구 삼청동(1111054000)      1,130      1,130       2       3       2
#
#      남_3세    남_4세    남_5세    남_6세  ...  여_91세  여_92세  여_93세  여_94세  여_95세  \
# 0  25,684  26,926  29,115  33,125  ...  5,718  4,987  4,157  3,135  2,326
# 1     261     299     320     426  ...    126    104     78     77     49
# 2      21      27      44      47  ...     13      4      6      5      2
# 3      21      24      30      37  ...     13      8      8      3      2
# 4       2       4       4       6  ...      1      5      0      2      0
#
#    여_96세  여_97세 여_98세 여_99세 여_100세 이상
# 0  1,504  1,032   773   704     1,292
# 1     29     20    13    15        28
# 2      3      0     2     1         2
# 3      4      3     0     3         0
# 4      0      1     0     0         2
#
# [5 rows x 207 columns]

# %%
#전처리한 데이터프레임 저장
df.to_csv('./data/population.csv')
# df를 바꾼걸 csv로 저장

# %%
new_df = pd.read_csv('./data/population.csv')
new_df.head()
# Out:
#    Unnamed: 0                         행정구역     남_총인구수  남_연령구간인구수    남_0세  \
# 0           0          서울특별시  (1100000000)  4,601,295  4,601,295  21,115
# 1           1       서울특별시 종로구 (1111000000)     69,408     69,408     232
# 2           2  서울특별시 종로구 청운효자동(1111051500)      5,392      5,392      24
# 3           3    서울특별시 종로구 사직동(1111053000)      4,124      4,124      17
# 4           4    서울특별시 종로구 삼청동(1111054000)      1,130      1,130       2
#
#      남_1세    남_2세    남_3세    남_4세    남_5세  ...  여_91세  여_92세  여_93세  여_94세  \
# 0  23,013  23,458  25,684  26,926  29,115  ...  5,718  4,987  4,157  3,135
# 1     248     270     261     299     320  ...    126    104     78     77
# 2      24      28      21      27      44  ...     13      4      6      5
# 3      14      15      21      24      30  ...     13      8      8      3
# 4       3       2       2       4       4  ...      1      5      0      2
#
#    여_95세  여_96세  여_97세 여_98세 여_99세 여_100세 이상
# 0  2,326  1,504  1,032   773   704     1,292
# 1     49     29     20    13    15        28
# 2      2      3      0     2     1         2
# 3      2      4      3     0     3         0
# 4      0      0      1     0     0         2
#
# [5 rows x 208 columns]

# %%
df.to_csv('./data/population_new.csv', index=False)
#불필요한 인덱스 위의 Unnamed 삭제

# %%
df.head()
# Out:
#                           행정구역     남_총인구수  남_연령구간인구수    남_0세    남_1세    남_2세  \
# 0          서울특별시  (1100000000)  4,601,295  4,601,295  21,115  23,013  23,458
# 1       서울특별시 종로구 (1111000000)     69,408     69,408     232     248     270
# 2  서울특별시 종로구 청운효자동(1111051500)      5,392      5,392      24      24      28
# 3    서울특별시 종로구 사직동(1111053000)      4,124      4,124      17      14      15
# 4    서울특별시 종로구 삼청동(1111054000)      1,130      1,130       2       3       2
#
#      남_3세    남_4세    남_5세    남_6세  ...  여_91세  여_92세  여_93세  여_94세  여_95세  \
# 0  25,684  26,926  29,115  33,125  ...  5,718  4,987  4,157  3,135  2,326
# 1     261     299     320     426  ...    126    104     78     77     49
# 2      21      27      44      47  ...     13      4      6      5      2
# 3      21      24      30      37  ...     13      8      8      3      2
# 4       2       4       4       6  ...      1      5      0      2      0
#
#    여_96세  여_97세 여_98세 여_99세 여_100세 이상
# 0  1,504  1,032   773   704     1,292
# 1     29     20    13    15        28
# 2      3      0     2     1         2
# 3      4      3     0     3         0
# 4      0      1     0     0         2
#
# [5 rows x 207 columns]

# %%
# 남자만 출력
# iloc 0, 3:104

# %%
# 여자만 출력
# iloc 0, 106

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3867 entries, 0 to 3866
# Columns: 207 entries, 행정구역 to 여_100세 이상
# dtypes: int64(8), object(199)
# memory usage: 6.1+ MB

# %%
df['컬럼명'].astype('int64')

# %%
df.iloc[:1:].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 df.iloc[:1:].astype('int64')
#
# File c:\Python39\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File c:\Python39\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File c:\Python39\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File c:\Python39\lib\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File c:\Python39\lib\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File c:\Python39\lib\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Python39\lib\site-packages\pandas\core\dtypes\cast.py:1098, in astype_nansafe(arr, dtype, copy, skipna)
#    1096 if arr.ndim > 1:
#    1097     flat = arr.ravel()
# -> 1098     result = astype_nansafe(flat, dtype, copy=copy, skipna=skipna)
#    1099     # error: Item "ExtensionArray" of "Union[ExtensionArray, ndarray]" has no
#    1100     # attribute "reshape"
#    1101     return result.reshape(arr.shape)  # type: ignore[union-attr]
#
# File c:\Python39\lib\site-packages\pandas\core\dtypes\cast.py:1154, in astype_nansafe(arr, dtype, copy, skipna)
#    1150 elif is_object_dtype(arr.dtype):
#    1151
#    1152     # work around NumPy brokenness, #1987
#    1153     if np.issubdtype(dtype.type, np.integer):
# -> 1154         return lib.astype_intsafe(arr, dtype)
#    1156     # if we have a datetime/timedelta array of objects
#    1157     # then coerce to a proper dtype and recall astype_nansafe
#    1159     elif is_datetime64_dtype(dtype):
#
# File c:\Python39\lib\site-packages\pandas\_libs\lib.pyx:668, in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '서울특별시  (1100000000)'

# %% [markdown]
# ## 데이터 전처리
# * 불필요 데이터 삭제
# * 컬럼0번째를 인덱스로 설정

# %%
# 행정구역을 index_col로 정하고 로드
df=pd.read_csv('./data/population_new.csv',index_col=0,thousands=',')
#콤마 삭제

# %%
df.head()
# Out:
#                               남_총인구수  남_연령구간인구수   남_0세   남_1세   남_2세   남_3세  \
# 행정구역
# 서울특별시  (1100000000)          4601295    4601295  21115  23013  23458  25684
# 서울특별시 종로구 (1111000000)         69408      69408    232    248    270    261
# 서울특별시 종로구 청운효자동(1111051500)     5392       5392     24     24     28     21
# 서울특별시 종로구 사직동(1111053000)       4124       4124     17     14     15     21
# 서울특별시 종로구 삼청동(1111054000)       1130       1130      2      3      2      2
#
#                               남_4세   남_5세   남_6세   남_7세  ...  여_91세  여_92세  \
# 행정구역                                                     ...
# 서울특별시  (1100000000)          26926  29115  33125  34405  ...   5718   4987
# 서울특별시 종로구 (1111000000)         299    320    426    399  ...    126    104
# 서울특별시 종로구 청운효자동(1111051500)     27     44     47     44  ...     13      4
# 서울특별시 종로구 사직동(1111053000)       24     30     37     45  ...     13      8
# 서울특별시 종로구 삼청동(1111054000)        4      4      6      7  ...      1      5
#
#                              여_93세  여_94세  여_95세  여_96세  여_97세  여_98세  여_99세  \
# 행정구역
# 서울특별시  (1100000000)           4157   3135   2326   1504   1032    773    704
# 서울특별시 종로구 (1111000000)          78     77     49     29     20     13     15
# 서울특별시 종로구 청운효자동(1111051500)      6      5      2      3      0      2      1
# 서울특별시 종로구 사직동(1111053000)        8      3      2      4      3      0      3
# 서울특별시 종로구 삼청동(1111054000)        0      2      0      0      1      0      0
#
#                              여_100세 이상
# 행정구역
# 서울특별시  (1100000000)               1292
# 서울특별시 종로구 (1111000000)              28
# 서울특별시 종로구 청운효자동(1111051500)          2
# 서울특별시 종로구 사직동(1111053000)            0
# 서울특별시 종로구 삼청동(1111054000)            2
#
# [5 rows x 206 columns]

# %% [markdown]
# > **[데이터에 대한 질문]**
# > * 종로구의 인구구조는 어떨까?
# > * 부산시 남구 문현동의 인구구조는 어떨가?
# >
# >

# %%
# 불필요한 데이터 삭제
#남_총인구수,남_연령구간인구수
#여_총인구수,여_연령구간인구수
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']

# %%
name = '아름동'

# %%
# 아름동이 있는지 확인
mytown = df[df.index.str.contains('아름동')]
mytown
# Out:
#                           남_0세  남_1세  남_2세  남_3세  남_4세  남_5세  남_6세  남_7세  \
# 행정구역
# 세종특별자치시  아름동(3611053000)    97   103    91   128   141   160   182   212
#
#                           남_8세  남_9세  ...  여_91세  여_92세  여_93세  여_94세  여_95세  \
# 행정구역                                  ...
# 세종특별자치시  아름동(3611053000)   213   203  ...      3      6      5      2      2
#
#                           여_96세  여_97세  여_98세  여_99세  여_100세 이상
# 행정구역
# 세종특별자치시  아름동(3611053000)      3      2      0      1          0
#
# [1 rows x 202 columns]

# %% [markdown]
# # 우리동네 연령별 인구구조
# * 남, 여 데이터 각각 추출

# %%
#남여 데이터 추출
male = mytown.iloc[:,0:101]
female = mytown.iloc[:,101:202]

# %%
male.shape, female.shape
# Out:
# ((1, 101), (1, 101))

# %%
#연령별 남여 합계 계산
total = []

for i in range(0,101):
    # print(male.iloc[0,i])

    total.append(male.iloc[0,i] + female.iloc[0,i])

# %%
total

# %% [markdown]
# ## line 차트

# %%
plt.figure(figsize=(5,4))
plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐

plt.title('{} 인구 구조'.format(name))

plt.plot(total)

plt.show()

# %% [markdown]
# > * 젊은 부부가 많이 사는 동네로 보입니다.
# > * 어린아이와 40대가 많이 살고 있고,
# > * 반면 노년층이 적습니다.

# %%
#전처리

#동네이름()

#시각화

#분석내용

# %% [markdown]
# ## Bar 차트
# * bar차트는 두 종류의 값들이 입력됩니다.
# * bar(막대를 표시할 위치, 막대 높이)
# * 두 종류의 값들은 개수가 일치해야 합니다.

# %%
plt.figure()
# plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐

plt.title('{} 인구 구조'.format(name))

plt.bar(range(101), total)

plt.show()

# %% [markdown]
# ## barh 차트

# %%
plt.figure()
# plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐

plt.title('{} 인구 구조'.format(name))

plt.barh(range(101), total)

plt.show()

# %% [markdown]
# ## 진짜 우리동네 인구구조

# %% [markdown]
# # 우리동네 남여 구조

# %%
#라이브러리 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 행정구역을 index_col로 정하고 로드
df=pd.read_csv('./data/population_new.csv',index_col=0,thousands=',')

# %%
# 불필요한 데이터 삭제
#남_총인구수,남_연령구간인구수
#여_총인구수,여_연령구간인구수
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']

# %%
name = '아름동'

mytown = df[df.index.str.contains('아름동')]

#남여 데이터 추출
male = mytown.iloc[:,0:101]
female = mytown.iloc[:,101:202]

#연령별 남여 합계 계산
total = []

for i in range(0,101):
    # print(male.iloc[0,i])

    total.append(male.iloc[0,i] + female.iloc[0,i])

# # plot 시각화
# plt.figure(figsize=(5,4))
# plt.style.use('ggplot')
# plt.rc('font', family = "Malgun Gothic") #한글사용
# plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐

# plt.title('{} 인구 구조'.format(name))

# plt.plot(total)

# plt.show()

# bar 시각화
plt.figure(figsize=(8,3))
plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐

plt.title('{} 인구 구조'.format(name))

plt.bar(range(101),male.iloc[0], label='남성')
plt.bar(range(101),female.iloc[0], label='여성')
plt.legend()
plt.show()

# %% [markdown]
# ## 모든 값 음수로 변환

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 행정구역을 index_col로 정하고 로드
df=pd.read_csv('./data/population_new.csv',index_col=0,thousands=',')

# 불필요한 데이터 삭제
#남_총인구수,남_연령구간인구수
#여_총인구수,여_연령구간인구수
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']

name = '아름동'

mytown = df[df.index.str.contains('아름동')]

#남여 데이터 추출
male = mytown.iloc[:,0:101]
female = mytown.iloc[:,101:202]

# 남자 음수로 전호나
temp = male*-1

#연령별 남여 합계 계산
total = []

for i in range(0,101):
    # print(male.iloc[0,i])

    total.append(male.iloc[0,i] + female.iloc[0,i])

# bar 시각화
plt.figure(figsize=(4,5))
plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐

plt.title('{} 인구 구조'.format(name))

plt.barh(range(101),temp.iloc[0], label='남성')
plt.barh(range(101),female.iloc[0], label='여성')
plt.legend()
plt.show()

# %% [markdown]
# > **[해석]**
# > *    ㅇㅇㅇ

# %% [markdown]
# ## 진짜 우리동네 남여 구조

# %%
# 위에 완료

# %% [markdown]
# # 바람부는 제주에는 정말 여성의 비율이 높을까?

# %% [markdown]
# ## 데이터 로딩 및 전처리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 

        
#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)]

m = mytown['남_총인구수'][0]
f = mytown['여_총인구수'][0]
m,f

## 중복데이터가 많이 나옴, 그중에서 0번째 데이터 사용할 것임
# Out:
# (340105, 338911)

# %% [markdown]
# ## pie 차트
# * 전체 데이터 중 특정 데이터의 비율을 보기 쉽게 표현합니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 
         

#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)]

m = mytown['남_총인구수'][0]
f = mytown['여_총인구수'][0]
m,f
# Out:
# (340105, 338911)

# %%
import matplotlib.pyplot as plt
plt.title('{} 남여 인구 구조'.format(name))
plt.pie([m,f] , labels=['남성','여성'] 
,autopct='%.1f%%',startangle=90 ,colors=['darkcyan','crimson'])
plt.rc('font',family='Malgun Gothic')

# %% [markdown]
# > **[해석]**
# > *   ㅋㅋㅋㅋ

# %% [markdown]
# ## line: 제주특별자치도 남여 인구 구조¶

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 

# 불필요한 데이터 삭제
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']


#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)] # 공백 데이터 처리

#남여 데이터 추출
male = mytown.iloc[0,0:101]
female = mytown.iloc[0,101:202]

# print(male.shape)


plt.figure(figsize=(10,5))
plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic")
plt.rcParams['axes.unicode_minus']=False

plt.title('{} 남여 인구 구조'.format(name))

plt.plot(range(101),male, label= '남성')
plt.plot(range(101),female, label= '여성')




plt.legend()
plt.show()

# %% [markdown]
# > * 항아리 모양 그래프보다 남녀 인구의 차이가 눈에 더 잘 들어옵니다.
# > * 좀 더 차이가 한 눈에 들어오도록 한다면?

# %% [markdown]
# ## bar:제주특별자치도 남여 인구 구조
#
# * 남자-여자를 뺀 값으로  막대그래프 그려봄

# %% [markdown]
# ### 데이터 로딩 및 전처리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 

# 불필요한 데이터 삭제
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']


#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)] # 공백 데이터 처리

#남여 데이터 추출
male = mytown.iloc[0,0:101]
female = mytown.iloc[0,101:202]

print(male-female)

# 남자-여자 연산 실패 --> index값이 같이 않아서...
# Out:
# 남_0세        NaN
# 남_100세 이상   NaN
# 남_10세       NaN
# 남_11세       NaN
# 남_12세       NaN
#              ..
# 여_96세       NaN
# 여_97세       NaN
# 여_98세       NaN
# 여_99세       NaN
# 여_9세        NaN
# Name: 제주특별자치도  (5000000000), Length: 202, dtype: float64

# %% [markdown]
# ### 남성에서 여성인구를 빼서 차이 정도를 시각화

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 

# 불필요한 데이터 삭제
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']


#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)] # 공백 데이터 처리

#남여 데이터 추출
male = mytown.iloc[0,0:101]
female = mytown.iloc[0,101:202]

#남-여 데이터 만들기
result = male.values - female.values 

plt.figure(figsize=(10,5))
plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic")
plt.rcParams['axes.unicode_minus']=False

plt.title('{} 남여 인구 구조'.format(name))

plt.bar(range(101),result)
plt.show()

# %% [markdown]
# > * 60대를 기준으로 그 이하의 연령대는 남성이 많지만,
# > * 60대 이상 인구는 여성이 많다는 것이 확연히 드러납니다.

# %% [markdown]
# ## scatter 차트
#
# * 데이터의 관계를 파악하는 데 도움이 되는 산점도 그래프입니다.
# * 산점도는 가로축과 세로축을 기준으로 두 요소가 서로 어떤 관계를 맺고 있는지를 파악하기 쉽게 나타낸 그래프입니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 

# 불필요한 데이터 삭제
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']


#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)] # 공백 데이터 처리

#남여 데이터 추출
male = mytown.iloc[0,0:101]
female = mytown.iloc[0,101:202]

#우리동네 연령별 총 인구수
total = []

for i in range(0,101):
    # print(mytown.iloc[0,i])
    total.append(mytown.iloc[0,i] + mytown.iloc[0,i+101])

# %%
plt.figure(figsize=(10,5))
plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic")
plt.rcParams['axes.unicode_minus']=False

plt.title('{} 남여 인구 구조'.format(name))


plt.scatter(male, female)
plt.show()

# %%
plt.scatter(male,female,c=range(101),s=total)
plt.show()

# %%
total[:5]
# Out:
# [3542, 3921, 4395, 4864, 5412]

# %%
import math

size = []

for i in range(101):
    size = math.sqrt(total[i])
    print(size)
    # sqrt 쓰는 이유 : 데이터 값의 크기를 줄이기 위해서

# %%
size
# Out:
# 14.594519519326424

# %%
plt.scatter(male,female,c=range(101),s=size, alpha=0.9, cmap='jet')

# cmap은 컬러맵
plt.show()

# %%
max(male),max(female)
# Out:
# (6935, 6452)

# %%
min(male),min(female)
# Out:
# (10, 72)

# %%
plt.scatter(male,female,c=range(101),s=size, alpha=0.9, cmap='jet')
plt.plot(range(max(male)), range(max(male)))
plt.show()
