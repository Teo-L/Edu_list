# %% [markdown]
# # 신경망 모델 훈련

# %% [markdown]
# * 사이킷런의 머신러닝 알고리즘은 좋은 성능을 내기 위해서 매개변수를 조정하고 훈련을 반복한다.
# * 이런 알고리즘은 모델의 구조가 고정되어 있다고 느낄 수 있다.
# * 반면 딥러닝에서는 모델의 구조를 직접 만든다는 느낌이 훨씬 강하다.
# * 층을 추가하고, 층에 있는 뉴런의 갯수, 활성화 함수를 결정할 일들이 많다.

# %% [markdown]
# ## 손실 곡선

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from sklearn.model_selection import train_test_split

# %%
#데이터 로드
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

#데이터 전처리
train_scaled = X_train / 255.0 # 0~255로 이루어진 데이터를 0~1사이의 값으로 정규화

#훈련, 검증 데이터 세트 분할
train_scaled, val_scaled, y_train, y_val = train_test_split(train_scaled, y_train, test_size=0.2, random_state=42)

# %%
#함수로 만들기


def model_fn(a_layer=None):
    model = Sequential()
    model.add(Flatten(input_shape=(28,28)))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
model = model_fn()

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 100)               78500
#
#  dense_3 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')

epoch_hist = model.fit(train_scaled, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.5219 - accuracy: 0.8172
# Epoch 2/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3904 - accuracy: 0.8585
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3468 - accuracy: 0.8732
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3242 - accuracy: 0.8812
# Epoch 5/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3037 - accuracy: 0.8889

# %%
 # 훈련 측정값
print(epoch_hist.history.keys())
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
epoch_hist.history['loss']
# Out:
# [0.521922767162323,
#  0.3903851807117462,
#  0.34679651260375977,
#  0.32419878244400024,
#  0.3036555051803589]

# %%
import matplotlib.pyplot as plt

#손실함수 값
plt.plot(epoch_hist.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
#정확도 그래프
plt.plot(epoch_hist.history['accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# > * 역시 에포크 마다 정확도가 올라간다. <br>
# > * 에포크를 더 많이 해야겠다.
# > * 인공 신경망 모델이 최적화하는 대상은 정확도가 아니라 **손실함수**입니다.

# %% [markdown]
# ## epoch:20 일때 손실함수

# %%
# 에포크 20으로 증가
model = model_fn()

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')


epoch_hist = model.fit(train_scaled, y_train, epochs=20)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.5259 - accuracy: 0.8181
# Epoch 2/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3992 - accuracy: 0.8567
# Epoch 3/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3558 - accuracy: 0.8714
# Epoch 4/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3305 - accuracy: 0.8801
# Epoch 5/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3100 - accuracy: 0.8860
# Epoch 6/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2938 - accuracy: 0.8917
# Epoch 7/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2854 - accuracy: 0.8938
# Epoch 8/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2692 - accuracy: 0.9003
# Epoch 9/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2613 - accuracy: 0.9023
# Epoch 10/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2516 - accuracy: 0.9076
# Epoch 11/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2433 - accuracy: 0.9099
# Epoch 12/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2367 - accuracy: 0.9128
# Epoch 13/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2302 - accuracy: 0.9143
# Epoch 14/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2206 - accuracy: 0.9180
# Epoch 15/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2142 - accuracy: 0.9200
# Epoch 16/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2071 - accuracy: 0.9228
# Epoch 17/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2032 - accuracy: 0.9234
# Epoch 18/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1955 - accuracy: 0.9262
# Epoch 19/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1932 - accuracy: 0.9271
# Epoch 20/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1889 - accuracy: 0.9300

# %%
#손실함수 값
plt.plot(epoch_hist.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
#정확도 그래프
plt.plot(epoch_hist.history['accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# ## 검증 손실
#
# * 경사 하강법을 사용했을 때 과대/과소 적합과 에포크 사이의 관계를 알아봤다.
# * 인공신경망은 모두 일종의 경사 하강법을 사용하기 때문에 동일한 개념이 적용된다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 검증용 데이터 세트를 튜플로 전달한다.
model = model_fn()

model.compile(optimizer='RMSProp', loss='sparse_categorical_crossentropy', metrics='accuracy')


epoch_hist = model.fit(train_scaled, y_train, epochs=20, batch_size = 50,
                        validation_data = (val_scaled,y_val))
# Out:
# Epoch 1/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.5453 - accuracy: 0.8084 - val_loss: 0.4451 - val_accuracy: 0.8382
# Epoch 2/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3961 - accuracy: 0.8563 - val_loss: 0.3967 - val_accuracy: 0.8568
# Epoch 3/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3537 - accuracy: 0.8711 - val_loss: 0.3696 - val_accuracy: 0.8666
# Epoch 4/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3297 - accuracy: 0.8808 - val_loss: 0.3594 - val_accuracy: 0.8693
# Epoch 5/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3132 - accuracy: 0.8866 - val_loss: 0.3476 - val_accuracy: 0.8767
# Epoch 6/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2989 - accuracy: 0.8907 - val_loss: 0.3322 - val_accuracy: 0.8824
# Epoch 7/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2867 - accuracy: 0.8956 - val_loss: 0.3364 - val_accuracy: 0.8811
# Epoch 8/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2782 - accuracy: 0.8990 - val_loss: 0.3519 - val_accuracy: 0.8796
# Epoch 9/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2697 - accuracy: 0.9028 - val_loss: 0.3581 - val_accuracy: 0.8813
# Epoch 10/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2612 - accuracy: 0.9052 - val_loss: 0.3455 - val_accuracy: 0.8852
# Epoch 11/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2542 - accuracy: 0.9078 - val_loss: 0.3780 - val_accuracy: 0.8769
# Epoch 12/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2477 - accuracy: 0.9109 - val_loss: 0.3795 - val_accuracy: 0.8775
# Epoch 13/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2403 - accuracy: 0.9131 - val_loss: 0.3558 - val_accuracy: 0.8832
# Epoch 14/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2375 - accuracy: 0.9147 - val_loss: 0.3947 - val_accuracy: 0.8772
# Epoch 15/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2311 - accuracy: 0.9162 - val_loss: 0.3909 - val_accuracy: 0.8812
# Epoch 16/20
# 960/960 [==============================] - 2s 3ms/step - loss: 0.2265 - accuracy: 0.9184 - val_loss: 0.3711 - val_accuracy: 0.8835
# Epoch 17/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2204 - accuracy: 0.9197 - val_loss: 0.4095 - val_accuracy: 0.8775
# Epoch 18/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2177 - accuracy: 0.9206 - val_loss: 0.3977 - val_accuracy: 0.8844
# Epoch 19/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2116 - accuracy: 0.9240 - val_loss: 0.3870 - val_accuracy: 0.8852
# Epoch 20/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2074 - accuracy: 0.9246 - val_loss: 0.4603 - val_accuracy: 0.8786

# %%
epoch_hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#손실함수 값
plt.plot(epoch_hist.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')

plt.plot(epoch_hist.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# > * 실행결과가 달라질 수 있음
# > * 초기에 검증 손실이 감소하다가 3번째 에포크만에 다시 상승하기 시작한다.
# > * 훈련 손실은 꾸준히 감소하기 때문에 과대적합 모델이 만들어 집니다.
# > * 검증 손실이 상승하는 시점을 가능한 뒤로 늦추면 검증 세트에 대한 손실이 줄어들 뿐만 아니라
# > * 검증 세트에 대한 정확도도 증가할 것 같다.

# %% [markdown]
# ## 딥러닝에서의 과대적합 해결
#
# 과대적합을 막는 가장 간단한 방법은 모델의 규모를 축소하는 것입니다. 즉, 모델에 있는 학습 가능한 파라미터의 수를 줄입니다(모델 파라미터는 층(layer)의 개수와 층의 유닛(unit) 개수에 의해 결정됩니다). 딥러닝에서는 모델의 학습 가능한 파라미터의 수를 종종 모델의 "용량"이라고 말합니다. 직관적으로 생각해 보면 많은 파라미터를 가진 모델이 더 많은 "기억 용량"을 가집니다. 이런 모델은 훈련 샘플과 타깃 사이를 일반화 능력이 없는 딕셔너리와 같은 매핑으로 완벽하게 학습할 수 있습니다. 하지만 이전에 본 적 없는 데이터에서 예측을 할 땐 쓸모가 없을 것입니다.
#
# 반면에 네트워크의 기억 용량이 부족하다면 이런 매핑을 쉽게 학습할 수 없을 것입니다. 손실을 최소화하기 위해서는 예측 성능이 더 많은 압축된 표현을 학습해야 합니다. 또한 너무 작은 모델을 만들면 훈련 데이터를 학습하기 어렵울 것입니다. "너무 많은 용량"과 "충분하지 않은 용량" 사이의 균형을 잡아야 합니다.
#
# 안타깝지만 어떤 모델의 (층의 개수나 뉴런 개수에 해당하는) 적절한 크기나 구조를 결정하는 마법같은 공식은 없습니다. 여러 가지 다른 구조를 사용해 실험을 해봐야만 합니다.
#
# 알맞은 모델의 크기를 찾으려면 비교적 적은 수의 층과 파라미터로 시작해서 검증 손실이 감소할 때까지 새로운 층을 추가하거나 층의 크기를 늘리는 것이 좋습니다.

# %% [markdown]
# ## 옵티마이저 종류와 성능

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# <center>
# <img src="https://mlfromscratch.com/content/images/2019/12/saddle.gif" width="400" height="300"  />
# </center>

# %% [markdown]
# ## 과대적합 방지: 옵티마이저 조정

# %%
# 옵티마이저 Adadelta사용해보기
model = model_fn()

model.compile(optimizer='Adadelta', loss='sparse_categorical_crossentropy', metrics='accuracy')


epoch_hist = model.fit(train_scaled, y_train, epochs=20, batch_size = 50,
                        validation_data = (val_scaled,y_val))
# Out:
# Epoch 1/20
# 960/960 [==============================] - 3s 3ms/step - loss: 2.3450 - accuracy: 0.1048 - val_loss: 2.1968 - val_accuracy: 0.1269
# Epoch 2/20
# 960/960 [==============================] - 3s 3ms/step - loss: 2.0851 - accuracy: 0.1894 - val_loss: 1.9825 - val_accuracy: 0.2617
# Epoch 3/20
# 960/960 [==============================] - 3s 3ms/step - loss: 1.8924 - accuracy: 0.3394 - val_loss: 1.8114 - val_accuracy: 0.4124
# Epoch 4/20
# 960/960 [==============================] - 3s 3ms/step - loss: 1.7336 - accuracy: 0.5017 - val_loss: 1.6674 - val_accuracy: 0.5526
# Epoch 5/20
# 960/960 [==============================] - 2s 3ms/step - loss: 1.5996 - accuracy: 0.6011 - val_loss: 1.5467 - val_accuracy: 0.6148
# Epoch 6/20
# 960/960 [==============================] - 3s 3ms/step - loss: 1.4870 - accuracy: 0.6380 - val_loss: 1.4450 - val_accuracy: 0.6373
# Epoch 7/20
# 960/960 [==============================] - 2s 3ms/step - loss: 1.3911 - accuracy: 0.6555 - val_loss: 1.3580 - val_accuracy: 0.6497
# Epoch 8/20
# 960/960 [==============================] - 2s 3ms/step - loss: 1.3099 - accuracy: 0.6674 - val_loss: 1.2845 - val_accuracy: 0.6590
# Epoch 9/20
# 960/960 [==============================] - 2s 3ms/step - loss: 1.2410 - accuracy: 0.6761 - val_loss: 1.2220 - val_accuracy: 0.6672
# Epoch 10/20
# 960/960 [==============================] - 2s 2ms/step - loss: 1.1822 - accuracy: 0.6826 - val_loss: 1.1686 - val_accuracy: 0.6732
# Epoch 11/20
# 960/960 [==============================] - 2s 3ms/step - loss: 1.1321 - accuracy: 0.6889 - val_loss: 1.1226 - val_accuracy: 0.6794
# Epoch 12/20
# 960/960 [==============================] - 2s 3ms/step - loss: 1.0884 - accuracy: 0.6951 - val_loss: 1.0823 - val_accuracy: 0.6853
# Epoch 13/20
# 960/960 [==============================] - 2s 3ms/step - loss: 1.0503 - accuracy: 0.7000 - val_loss: 1.0474 - val_accuracy: 0.6915
# Epoch 14/20
# 960/960 [==============================] - 3s 3ms/step - loss: 1.0172 - accuracy: 0.7053 - val_loss: 1.0166 - val_accuracy: 0.6975
# Epoch 15/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.9879 - accuracy: 0.7104 - val_loss: 0.9895 - val_accuracy: 0.7018
# Epoch 16/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.9620 - accuracy: 0.7159 - val_loss: 0.9654 - val_accuracy: 0.7062
# Epoch 17/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.9390 - accuracy: 0.7193 - val_loss: 0.9438 - val_accuracy: 0.7103
# Epoch 18/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.9182 - accuracy: 0.7240 - val_loss: 0.9241 - val_accuracy: 0.7148
# Epoch 19/20
# 960/960 [==============================] - 2s 3ms/step - loss: 0.8991 - accuracy: 0.7289 - val_loss: 0.9062 - val_accuracy: 0.7187
# Epoch 20/20
# 960/960 [==============================] - 2s 3ms/step - loss: 0.8818 - accuracy: 0.7322 - val_loss: 0.8898 - val_accuracy: 0.7226

# %%
#손실함수 값
plt.plot(epoch_hist.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')

plt.plot(epoch_hist.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# 옵티마이저 Adam 사용하기
model = model_fn()

model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics='accuracy')


epoch_hist = model.fit(train_scaled, y_train, epochs=20, batch_size = 50,
                        validation_data = (val_scaled,y_val))
# Out:
# Epoch 1/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.5410 - accuracy: 0.8122 - val_loss: 0.4359 - val_accuracy: 0.8458
# Epoch 2/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.4065 - accuracy: 0.8550 - val_loss: 0.4043 - val_accuracy: 0.8578
# Epoch 3/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3622 - accuracy: 0.8698 - val_loss: 0.3600 - val_accuracy: 0.8713
# Epoch 4/20
# 960/960 [==============================] - 2s 3ms/step - loss: 0.3358 - accuracy: 0.8767 - val_loss: 0.3678 - val_accuracy: 0.8674
# Epoch 5/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3132 - accuracy: 0.8849 - val_loss: 0.3379 - val_accuracy: 0.8784
# Epoch 6/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3019 - accuracy: 0.8899 - val_loss: 0.3368 - val_accuracy: 0.8777
# Epoch 7/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.2858 - accuracy: 0.8937 - val_loss: 0.3342 - val_accuracy: 0.8775
# Epoch 8/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.2707 - accuracy: 0.9006 - val_loss: 0.3211 - val_accuracy: 0.8811
# Epoch 9/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.2648 - accuracy: 0.9018 - val_loss: 0.3231 - val_accuracy: 0.8814
# Epoch 10/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.2530 - accuracy: 0.9068 - val_loss: 0.3257 - val_accuracy: 0.8846
# Epoch 11/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.2447 - accuracy: 0.9095 - val_loss: 0.3198 - val_accuracy: 0.8846
# Epoch 12/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.2364 - accuracy: 0.9115 - val_loss: 0.3171 - val_accuracy: 0.8873
# Epoch 13/20
# 960/960 [==============================] - 2s 3ms/step - loss: 0.2294 - accuracy: 0.9159 - val_loss: 0.3165 - val_accuracy: 0.8867
# Epoch 14/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2219 - accuracy: 0.9164 - val_loss: 0.3186 - val_accuracy: 0.8871
# Epoch 15/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.2171 - accuracy: 0.9204 - val_loss: 0.3334 - val_accuracy: 0.8825
# Epoch 16/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2099 - accuracy: 0.9227 - val_loss: 0.3442 - val_accuracy: 0.8777
# Epoch 17/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2034 - accuracy: 0.9246 - val_loss: 0.3187 - val_accuracy: 0.8896
# Epoch 18/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.1992 - accuracy: 0.9267 - val_loss: 0.3335 - val_accuracy: 0.8871
# Epoch 19/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.1931 - accuracy: 0.9281 - val_loss: 0.3253 - val_accuracy: 0.8865
# Epoch 20/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.1912 - accuracy: 0.9282 - val_loss: 0.3228 - val_accuracy: 0.8875

# %%
#손실함수 값
plt.plot(epoch_hist.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')

plt.plot(epoch_hist.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# > 검증 손실 그래프에 여전히 요동이 있지만 10번째 에포크까지 감소 추세가 이어지고 있다. <br>
# > Adam 옵티마이저가 이 데이터 셋에 잘 맞는다는 것을 보여준다. <br>
# > 더 나은 곡선을 얻기위해서는 학습률을 조정에 도전!!

# %% [markdown]
# ## 과대적합 방지: 옵티마이저 조정 + 학습률 튜닝

# %%
model = model_fn()

adam = keras.optimizers.Adam(learning_rate=0.01) # default : 0.001

model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics='accuracy')


epoch_hist = model.fit(train_scaled, y_train, epochs=6,
                        validation_data = (val_scaled,y_val))
# Out:
# Epoch 1/6
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5280 - accuracy: 0.8165 - val_loss: 0.4066 - val_accuracy: 0.8537
# Epoch 2/6
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3931 - accuracy: 0.8587 - val_loss: 0.3757 - val_accuracy: 0.8645
# Epoch 3/6
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3523 - accuracy: 0.8718 - val_loss: 0.3567 - val_accuracy: 0.8692
# Epoch 4/6
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3279 - accuracy: 0.8793 - val_loss: 0.3455 - val_accuracy: 0.8771
# Epoch 5/6
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3078 - accuracy: 0.8856 - val_loss: 0.3313 - val_accuracy: 0.8772
# Epoch 6/6
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2921 - accuracy: 0.8912 - val_loss: 0.3277 - val_accuracy: 0.8802

# %%
#손실함수 값
plt.plot(epoch_hist.history['loss'], label='train')
plt.xlabel('epoch')
plt.ylabel('loss')

plt.plot(epoch_hist.history['val_loss'], label = 'val')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %% [markdown]
# > 학습률 조정이 과대적합을 방지할 수 있지만, 적정한 튜닝값을 찾기에 쉽지 않다.

# %% [markdown]
# ## 드롭아웃
#
# * 랜덤하게 은닉층의 뉴런이 드롭아웃된다.
# * 드롭아웃은 과대적합을 막는다.
# * 이전 층의 뉴런이 랜덤하게 꺼지면서 특정 뉴런에 과대하게 의존하는 것을 줄이고, 모든 입력에 대해 주의를 기울여야 하기 때문이다.
#
# * 마치 2개의 신경망을 앙상블 하는 것과 같다.
# * 앙상블은 과대적합을 막는데 아주 좋은 기법이다.

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# <center>
# <img src="http://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/04/1IrdJ5PghD9YoOyVAQ73MJw.gif" width="400" height="300"  />
# </center>

# %%
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(Flatten(input_shape=(28, 28))) #플래튼 층 reshape() 대신 사용하면 편리 -> 층으로 카운트 하진 않음
model.add(Dense(100, activation='relu')) #렐루함수
model.add(Dropout(0.3)) #층 하나를 추가하고, 30%정도를 드롭아웃한다. 즉 훈련되는 파라미터가 없도록
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_19 (Flatten)        (None, 784)               0
#
#  dense_38 (Dense)            (None, 100)               78500
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_39 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics='accuracy')


history = model.fit(train_scaled, y_train, epochs=20,
                    validation_data=(val_scaled, y_val))
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5934 - accuracy: 0.7922 - val_loss: 0.4212 - val_accuracy: 0.8485
# Epoch 2/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4406 - accuracy: 0.8424 - val_loss: 0.3834 - val_accuracy: 0.8622
# Epoch 3/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4058 - accuracy: 0.8520 - val_loss: 0.3904 - val_accuracy: 0.8533
# Epoch 4/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3842 - accuracy: 0.8603 - val_loss: 0.3667 - val_accuracy: 0.8650
# Epoch 5/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3713 - accuracy: 0.8651 - val_loss: 0.3629 - val_accuracy: 0.8655
# Epoch 6/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3559 - accuracy: 0.8683 - val_loss: 0.3434 - val_accuracy: 0.8724
# Epoch 7/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3453 - accuracy: 0.8730 - val_loss: 0.3388 - val_accuracy: 0.8736
# Epoch 8/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3376 - accuracy: 0.8745 - val_loss: 0.3344 - val_accuracy: 0.8758
# Epoch 9/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3279 - accuracy: 0.8774 - val_loss: 0.3423 - val_accuracy: 0.8779
# Epoch 10/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3243 - accuracy: 0.8807 - val_loss: 0.3356 - val_accuracy: 0.8764
# Epoch 11/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3200 - accuracy: 0.8820 - val_loss: 0.3251 - val_accuracy: 0.8851
# Epoch 12/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3115 - accuracy: 0.8844 - val_loss: 0.3364 - val_accuracy: 0.8753
# Epoch 13/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3070 - accuracy: 0.8860 - val_loss: 0.3282 - val_accuracy: 0.8814
# Epoch 14/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3018 - accuracy: 0.8856 - val_loss: 0.3251 - val_accuracy: 0.8848
# Epoch 15/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2987 - accuracy: 0.8885 - val_loss: 0.3223 - val_accuracy: 0.8845
# Epoch 16/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2929 - accuracy: 0.8899 - val_loss: 0.3353 - val_accuracy: 0.8843
# Epoch 17/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2896 - accuracy: 0.8911 - val_loss: 0.3250 - val_accuracy: 0.8842
# Epoch 18/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2879 - accuracy: 0.8917 - val_loss: 0.3218 - val_accuracy: 0.8853
# Epoch 19/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2830 - accuracy: 0.8937 - val_loss: 0.3277 - val_accuracy: 0.8827
# Epoch 20/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2785 - accuracy: 0.8941 - val_loss: 0.3352 - val_accuracy: 0.8802

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# > 과대적합이 확실이 많이 줄었다.
# >  에포크 10회 이상이 되더라도 다소 검증 손실의 감소 추세가 떨어지기는 했지만 그래도 크게 상승하지는 않고 어느 정도 유지되고 있다.
#
# >  적정한 에포크 횟수를 알았으니 10회로 훈련해야겠다.

# %% [markdown]
# ## 모델 저장과 복원

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28))) #플래튼 층 reshape() 대신 사용하면 편리 -> 층으로 카운트 하진 않음
model.add(Dense(100, activation='relu')) #렐루함수

model.add(Dropout(0.3)) # 층 하나를 추가한다. 30%정도를 드롭아웃한다.  훈련되는 파라미터는 없다. 검증시에는 드롭아웃 하지 않고, 훈련시에만 드롭아웃 기능 사용
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')

# %%
#에포크 10회로 조정
history = model.fit(train_scaled, y_train, epochs=10,verbose=0,
                    validation_data=(val_scaled, y_val))

# %%
 #훈련된 모델의 파라미터를 저장함
model.save_weights('./model/mnist_fashion_weights.h5')

# %%
#모델 구조와 모델 파라미터를 함께 저장 HDF5 포맷으로 저장
model.save('./model/mnist_fashion_weights.h5')

# %% [markdown]
# ## 모델 복원: 가중치 활용

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Dropout
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import numpy as np

# %%
# 훈련하지 않은 새로운 모델에 저장해둔 파라미터들을 적재해서 

model = Sequential()
model.add(Flatten(input_shape=(28, 28))) #플래튼 층 reshape() 대신 사용하면 편리 -> 층으로 카운트 하진 않음
model.add(Dense(100, activation='relu')) #렐루함수

model.add(Dropout(0.3)) # 층 하나를 추가한다. 30%정도를 드롭아웃한다.  훈련되는 파라미터는 없다. 검증시에는 드롭아웃 하지 않고, 훈련시에만 드롭아웃 기능 사용
model.add(Dense(10, activation='softmax'))

# %%
model.load_weights('./model/mnist_fashion_weights.h5')

# %%
#데이터 로드
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

#데이터 전처리
train_scaled = X_train / 255.0 # 0~255로 이루어진 데이터를 0~1사이의 값으로 정규화

#훈련, 검증 데이터 세트 분할
train_scaled, val_scaled, y_train, y_val = train_test_split(train_scaled, y_train, test_size=0.2, random_state=42)

# %%
# 예측
pred = model.predict(val_scaled)
# Out:
# 375/375 [==============================] - 1s 2ms/step

# %%
# 10개 클래스에 대한 확률이 들어 있다.
# Out:
# array([2.7487927e-11, 3.1238704e-14, 2.6877838e-13, 6.9180924e-13,
#        1.0230102e-10, 1.0403652e-07, 9.9493256e-14, 9.8945546e-11,
#        9.9999988e-01, 6.8884140e-13], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#10개의 클래스에 대한 예측 확률
pred[0]
# Out:
# array([2.7487927e-11, 3.1238704e-14, 2.6877838e-13, 6.9180924e-13,
#        1.0230102e-10, 1.0403652e-07, 9.9493256e-14, 9.8945546e-11,
#        9.9999988e-01, 6.8884140e-13], dtype=float32)

# %%
#가장 큰 값이 있는 인덱스, 8인덱스의 클래스
# Out:
# 8

# %%
# 10개중에 가장 큰 값
# Out:
# 375/375 [==============================] - 0s 753us/step
# array([8, 8, 7, ..., 8, 8, 6], dtype=int64)

# %%
#예측값과 실제값 비교
# Out:
# (4, 4)

# %%
# Out:
# array([ True,  True,  True, ...,  True,  True, False])

# %%
 #예측값과 실제값이 맞은 평균
# Out:
# 0.8783333333333333

# %% [markdown]
# ### 모델 재활용

# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split

(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

train_scaled = X_train / 255.0 # 0~255로 이루어진 데이터를 0~1사이의 값으로 정규화

train_scaled, val_scaled, y_train, y_val = train_test_split(train_scaled, y_train, test_size=0.2, random_state=42)

# %%
X_test_scaled =  X_test/255.0

model.evaluate(X_test_scaled, y_test)
# Out:
# 313/313 [==============================] - 0s 920us/step - loss: 0.3570 - accuracy: 0.8736
# [0.3570030629634857, 0.8736000061035156]

# %%
import numpy as np

test_labels = np.argmax(model.predict(X_test_scaled), axis=-1)
test_labels[3],y_test[3] #예측값과 실제값 비교
# Out:
# 313/313 [==============================] - 0s 884us/step
# (1, 1)

# %% [markdown]
# ## 콜백과 조기종료
#
# * 콜백은 훈련 과정 중간에 어떤 작업을 수행할 수 있게 하는 객체입니다.
#
#
# * ModelCheckpoint
#     * 최상의 검증 점수를 낸 그 순간의 가중치를 자동으로 저장해 줍니다.
# * EarlyStopping
#     * 과대적합이 시작되기 전에 훈련을 미리 중지하는 것을 조기 종료라고 합니다.
#     * 에포크가 남아있어도 학습을 중단해 줍니다.
#
#
# * 그러면 자원을 아낄 수 있습니다.
# * 조기 종료는 에포크 횟수를 제한하는 역할도 하지만
# * 모델이 과적합되는 것을 막아 주기 때문에 규제 방법 중 하나로 생각할 수 있습니다.

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28))) #플래튼 층 reshape() 대신 사용하면 편리 -> 층으로 카운트 하진 않음
model.add(Dense(100, activation='relu')) #렐루함수

model.add(Dropout(0.3)) # 층 하나를 추가한다. 30%정도를 드롭아웃한다.  훈련되는 파라미터는 없다. 검증시에는 드롭아웃 하지 않고, 훈련시에만 드롭아웃 기능 사용
model.add(Dense(10, activation='softmax'))


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')

# %%
history = model.fit(train_scaled, y_train, epochs=20, verbose=1,
                    validation_data=(val_scaled, y_val))

# %%
# 몇 번째 에포크에서 훈련이 중지 되었는지..
# Out:
# 7

# %%
# 최적의 상태일 때 모델을 저장해주기 때문에 검증 세트로 확인
# Out:
# 313/313 [==============================] - 0s 939us/step - loss: 0.3555 - accuracy: 0.8791
# [0.355545312166214, 0.8791000247001648]

# %% [markdown]
# # 종합코드

# %%
# Out:
# Epoch 1/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.6846 - accuracy: 0.7640 - val_loss: 0.4684 - val_accuracy: 0.8366
# Epoch 2/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.4701 - accuracy: 0.8368 - val_loss: 0.4075 - val_accuracy: 0.8568
# Epoch 3/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.4222 - accuracy: 0.8488 - val_loss: 0.3847 - val_accuracy: 0.8629
# Epoch 4/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3947 - accuracy: 0.8602 - val_loss: 0.3672 - val_accuracy: 0.8671
# Epoch 5/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3781 - accuracy: 0.8641 - val_loss: 0.3618 - val_accuracy: 0.8700
# Epoch 6/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3625 - accuracy: 0.8696 - val_loss: 0.3449 - val_accuracy: 0.8755
# Epoch 7/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3512 - accuracy: 0.8730 - val_loss: 0.3415 - val_accuracy: 0.8762
# Epoch 8/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3387 - accuracy: 0.8760 - val_loss: 0.3387 - val_accuracy: 0.8742
# Epoch 9/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3329 - accuracy: 0.8784 - val_loss: 0.3329 - val_accuracy: 0.8788
# Epoch 10/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3303 - accuracy: 0.8801 - val_loss: 0.3337 - val_accuracy: 0.8773
# Epoch 11/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3227 - accuracy: 0.8816 - val_loss: 0.3259 - val_accuracy: 0.8810
# Epoch 12/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3158 - accuracy: 0.8858 - val_loss: 0.3194 - val_accuracy: 0.8824
# Epoch 13/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3101 - accuracy: 0.8862 - val_loss: 0.3205 - val_accuracy: 0.8819
# Epoch 14/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3037 - accuracy: 0.8892 - val_loss: 0.3229 - val_accuracy: 0.8842
# 13
# 375/375 [==============================] - 0s 890us/step - loss: 0.3194 - accuracy: 0.8824
# [0.3194139301776886, 0.8824166655540466]

# %%
X_test_scaled = X_test / 255.0

model.evaluate(X_test_scaled, y_test)
# Out:
# 313/313 [==============================] - 0s 995us/step - loss: 0.3445 - accuracy: 0.8754
# [0.34445440769195557, 0.8754000067710876]

# %% [markdown]
# ## 심화
#
# * Dense층의 개수를 늘리고, 그 안의 units 개수를 조정하여 성능향상을 시도하세요.
# * 배치 사이즈를 조정하여 성능향상을 시도하세요.
